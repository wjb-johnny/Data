# %% [markdown]
# # How to Meet and Retrieve Your Data

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/capstone 
# %sql USE capstone
# Out:
# 0 rows affected.
# []

# %% [markdown]
# # Relational schema

# %% [markdown]
# # Explore the dataset

# %%
# %%sql
# SHOW tables
# Out:
# 6 rows affected.
# [('location',),
#  ('property_type',),
#  ('st_property_info',),
#  ('st_rental_dates',),
#  ('st_rental_prices',),
#  ('watershed_property_info',)]

# %%
# %%sql
# DESCRIBE location
# Out:
# 4 rows affected.
# [('location_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zipcode', 'int(5)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT  *
# FROM location
# LIMIT 10
# Out:
# 10 rows affected.
# [('L1', 'Anchorage', 'AK', 99501),
#  ('L10', 'Anchorage', 'AK', 99518),
#  ('L100', 'Cherokee', 'AL', 35616),
#  ('L1000', 'Azusa', 'CA', 91702),
#  ('L10000', 'Winston-Sa', 'NC', 27101),
#  ('L10001', 'Winston-Sa', 'NC', 27103),
#  ('L10002', 'Winston-Sa', 'NC', 27104),
#  ('L10003', 'Winston-Sa', 'NC', 27105),
#  ('L10004', 'Winston-Sa', 'NC', 27106),
#  ('L10005', 'Winston-Sa', 'NC', 27107)]

# %%
# %%sql
# DESCRIBE property_type
# Out:
# 5 rows affected.
# [('property_type_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('apt_house', 'varchar(255)', 'YES', '', None, ''),
#  ('num_bedrooms', 'varchar(255)', 'YES', '', None, ''),
#  ('kitchen', 'varchar(255)', 'YES', '', None, ''),
#  ('shared', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT  *
# FROM property_type
# LIMIT 10
# Out:
# 10 rows affected.
# [('R1', 'apartment', '1', 'Y', 'Y'),
#  ('R10', 'house', '1', 'Y', 'N'),
#  ('R11', 'house', '1', 'N', 'Y'),
#  ('R12', 'house', '1', 'N', 'N'),
#  ('R13', 'house', '2', 'Y', 'Y'),
#  ('R14', 'house', '2', 'Y', 'N'),
#  ('R15', 'house', '2', 'N', 'Y'),
#  ('R16', 'house', '2', 'N', 'N'),
#  ('R2', 'apartment', '1', 'Y', 'N'),
#  ('R3', 'apartment', '1', 'N', 'Y')]

# %%
# %sql DESCRIBE st_property_info
# Out:
# 3 rows affected.
# [('st_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT  *
# FROM st_property_info
# LIMIT 10
# Out:
# 10 rows affected.
# [('ST1', 'L9531', 'R6'),
#  ('ST10', 'L9533', 'R6'),
#  ('ST100', 'L1944', 'R2'),
#  ('ST1000', 'L5957', 'R1'),
#  ('ST101', 'L15257', 'R2'),
#  ('ST102', 'L15257', 'R6'),
#  ('ST103', 'L15257', 'R10'),
#  ('ST104', 'L15257', 'R14'),
#  ('ST105', 'L15260', 'R2'),
#  ('ST106', 'L15260', 'R6')]

# %%
# %sql DESCRIBE st_rental_dates
# Out:
# 2 rows affected.
# [('rental_date', 'date', 'NO', 'PRI', None, ''),
#  ('st_property', 'varchar(255)', 'NO', 'PRI', None, '')]

# %%
# %%sql
# SELECT  *
# FROM st_rental_dates
# LIMIT 10
# Out:
# 10 rows affected.
# [(datetime.date(2014, 1, 31), 'ST100'),
#  (datetime.date(2014, 1, 31), 'ST106'),
#  (datetime.date(2014, 1, 31), 'ST107'),
#  (datetime.date(2014, 1, 31), 'ST109'),
#  (datetime.date(2014, 1, 31), 'ST113'),
#  (datetime.date(2014, 1, 31), 'ST114'),
#  (datetime.date(2014, 1, 31), 'ST116'),
#  (datetime.date(2014, 1, 31), 'ST118'),
#  (datetime.date(2014, 1, 31), 'ST119'),
#  (datetime.date(2014, 1, 31), 'ST123')]

# %%
# %sql DESCRIBE st_rental_prices
# Out:
# 5 rows affected.
# [('location', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('property_type', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('percentile_10th_price', 'int(11)', 'YES', '', None, ''),
#  ('percentile_90th_price', 'int(11)', 'YES', '', None, ''),
#  ('sample_nightly_rent_price', 'int(11)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT  *
# FROM st_rental_prices
# LIMIT 10
# Out:
# 10 rows affected.
# [('L10126', 'R1', 83, 273, 192),
#  ('L10126', 'R10', 155, 494, 257),
#  ('L10126', 'R11', 82, 411, 242),
#  ('L10126', 'R12', 119, 366, 229),
#  ('L10126', 'R13', 137, 416, 375),
#  ('L10126', 'R14', 151, 391, 286),
#  ('L10126', 'R15', 116, 312, 172),
#  ('L10126', 'R16', 126, 343, 258),
#  ('L10126', 'R2', 91, 342, 229),
#  ('L10126', 'R3', 41, 242, 117)]

# %%
# %sql DESCRIBE watershed_property_info
# Out:
# 4 rows affected.
# [('ws_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, ''),
#  ('current_monthly_rent', 'int(11)', 'NO', '', None, '')]

# %%
# %%sql
# SELECT  *
# FROM watershed_property_info
# LIMIT 10
# Out:
# 10 rows affected.
# [('W1', 'L9531', 'R6', 1060),
#  ('W10', 'L9533', 'R6', 1200),
#  ('W100', 'L1944', 'R2', 3300),
#  ('W101', 'L15257', 'R2', 1400),
#  ('W102', 'L15257', 'R6', 2000),
#  ('W103', 'L15257', 'R10', 1600),
#  ('W104', 'L15257', 'R14', 2800),
#  ('W105', 'L15260', 'R2', 1100),
#  ('W106', 'L15260', 'R6', 1900),
#  ('W107', 'L15260', 'R10', 1800)]

# %%
# %%sql
# SELECT *
# FROM watershed_property_info ws
# LEFT JOIN property_type pt ON ws.property_type = pt.property_type_id
# LEFT JOIN location loc ON ws.location = loc.location_id
# Out:
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060, 'R6', 'apartment', '2', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W10', 'L9533', 'R6', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W100', 'L1944', 'R2', 3300, 'R2', 'apartment', '1', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W101', 'L15257', 'R2', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W102', 'L15257', 'R6', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W103', 'L15257', 'R10', 1600, 'R10', 'house', '1', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W104', 'L15257', 'R14', 2800, 'R14', 'house', '2', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W105', 'L15260', 'R2', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W106', 'L15260', 'R6', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W107', 'L15260', 'R10', 1800, 'R10', 'house', '1', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W108', 'L15260', 'R14', 3200, 'R14', 'house', '2', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W109', 'L15264', 'R2', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W11', 'L9533', 'R10', 1000, 'R10', 'house', '1', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W110', 'L15264', 'R6', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W111', 'L15264', 'R10', 1200, 'R10', 'house', '1', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W112', 'L15264', 'R14', 1600, 'R14', 'house', '2', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W113', 'L15278', 'R2', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W114', 'L15278', 'R6', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W115', 'L15278', 'R10', 900, 'R10', 'house', '1', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W116', 'L15278', 'R14', 1100, 'R14', 'house', '2', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W117', 'L15280', 'R2', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W118', 'L15280', 'R6', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W119', 'L15280', 'R10', 1500, 'R10', 'house', '1', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W12', 'L9533', 'R14', 1300, 'R14', 'house', '2', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W120', 'L15280', 'R14', 1600, 'R14', 'house', '2', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W121', 'L463', 'R2', 600, 'R2', 'apartment', '1', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W122', 'L463', 'R6', 800, 'R6', 'apartment', '2', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W123', 'L463', 'R10', 700, 'R10', 'house', '1', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W124', 'L463', 'R14', 1000, 'R14', 'house', '2', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W125', 'L464', 'R2', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W126', 'L464', 'R6', 900, 'R6', 'apartment', '2', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W127', 'L464', 'R10', 1000, 'R10', 'house', '1', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W128', 'L464', 'R14', 1200, 'R14', 'house', '2', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W129', 'L2314', 'R2', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W13', 'L9534', 'R6', 920, 'R6', 'apartment', '2', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W130', 'L2314', 'R6', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W131', 'L2314', 'R10', 1100, 'R10', 'house', '1', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W132', 'L2314', 'R14', 1200, 'R14', 'house', '2', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W133', 'L2318', 'R2', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W134', 'L2318', 'R6', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W135', 'L2318', 'R10', 1200, 'R10', 'house', '1', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W136', 'L2318', 'R14', 1900, 'R14', 'house', '2', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W137', 'L2323', 'R2', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W138', 'L2323', 'R6', 1500, 'R6', 'apartment', '2', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W139', 'L2323', 'R10', 1300, 'R10', 'house', '1', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W14', 'L9534', 'R10', 850, 'R10', 'house', '1', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W140', 'L2323', 'R14', 1800, 'R14', 'house', '2', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W141', 'L2325', 'R2', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W142', 'L2325', 'R6', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W143', 'L2325', 'R10', 1300, 'R10', 'house', '1', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W144', 'L2325', 'R14', 1900, 'R14', 'house', '2', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W145', 'L2338', 'R2', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W146', 'L2338', 'R6', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W147', 'L2338', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W148', 'L2338', 'R14', 1700, 'R14', 'house', '2', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W149', 'L3244', 'R2', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W15', 'L9534', 'R14', 900, 'R14', 'house', '2', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W150', 'L3244', 'R6', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W151', 'L3244', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W152', 'L3244', 'R14', 1900, 'R14', 'house', '2', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W153', 'L3256', 'R2', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W154', 'L3256', 'R6', 2400, 'R6', 'apartment', '2', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W155', 'L3256', 'R10', 2100, 'R10', 'house', '1', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W156', 'L3256', 'R14', 3200, 'R14', 'house', '2', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W157', 'L3261', 'R2', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W158', 'L3261', 'R6', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W159', 'L3261', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W16', 'L9534', 'R2', 750, 'R2', 'apartment', '1', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W160', 'L3261', 'R14', 1900, 'R14', 'house', '2', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W161', 'L3262', 'R2', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W162', 'L3262', 'R6', 2200, 'R6', 'apartment', '2', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W163', 'L3262', 'R10', 1500, 'R10', 'house', '1', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W164', 'L3262', 'R14', 2400, 'R14', 'house', '2', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W165', 'L3264', 'R2', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W166', 'L3264', 'R6', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W167', 'L3264', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W168', 'L3264', 'R14', 2000, 'R14', 'house', '2', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W169', 'L10126', 'R2', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W17', 'L4761', 'R6', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W170', 'L10126', 'R6', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W171', 'L10126', 'R10', 1300, 'R10', 'house', '1', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W172', 'L10126', 'R14', 1800, 'R14', 'house', '2', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W173', 'L10130', 'R2', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W174', 'L10130', 'R6', 900, 'R6', 'apartment', '2', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W175', 'L10130', 'R10', 1000, 'R10', 'house', '1', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W176', 'L10130', 'R14', 1200, 'R14', 'house', '2', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W177', 'L10133', 'R2', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W178', 'L10133', 'R6', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W179', 'L10133', 'R10', 800, 'R10', 'house', '1', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W18', 'L4761', 'R10', 2500, 'R10', 'house', '1', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W180', 'L10133', 'R14', 900, 'R14', 'house', '2', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W181', 'L10136', 'R2', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W182', 'L10136', 'R6', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W183', 'L10136', 'R10', 900, 'R10', 'house', '1', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W184', 'L10136', 'R14', 1200, 'R14', 'house', '2', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W185', 'L1882', 'R2', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W186', 'L1882', 'R6', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W187', 'L1882', 'R10', 1300, 'R10', 'house', '1', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W188', 'L1882', 'R14', 1900, 'R14', 'house', '2', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W189', 'L1883', 'R2', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W19', 'L4761', 'R14', 2800, 'R14', 'house', '2', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W190', 'L1883', 'R6', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W191', 'L1883', 'R10', 1300, 'R10', 'house', '1', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W192', 'L1883', 'R14', 1600, 'R14', 'house', '2', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W193', 'L1887', 'R2', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W194', 'L1887', 'R6', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W195', 'L1887', 'R10', 1700, 'R10', 'house', '1', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W196', 'L1887', 'R14', 2500, 'R14', 'house', '2', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W197', 'L1902', 'R2', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W198', 'L1902', 'R6', 2600, 'R6', 'apartment', '2', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W199', 'L1902', 'R10', 2500, 'R10', 'house', '1', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W2', 'L9531', 'R10', 1500, 'R10', 'house', '1', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W20', 'L4761', 'R2', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W200', 'L1902', 'R14', 3600, 'R14', 'house', '2', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W201', 'L1916', 'R2', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W202', 'L1916', 'R6', 1600, 'R6', 'apartment', '2', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W203', 'L1916', 'R10', 1000, 'R10', 'house', '1', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W204', 'L1916', 'R14', 1500, 'R14', 'house', '2', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W205', 'L12252', 'R2', 750, 'R2', 'apartment', '1', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W206', 'L12252', 'R6', 1040, 'R6', 'apartment', '2', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W207', 'L12252', 'R10', 900, 'R10', 'house', '1', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W208', 'L12252', 'R14', 1400, 'R14', 'house', '2', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W209', 'L12260', 'R2', 825, 'R2', 'apartment', '1', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W21', 'L4765', 'R6', 2700, 'R6', 'apartment', '2', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W210', 'L12260', 'R6', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W211', 'L12260', 'R10', 1000, 'R10', 'house', '1', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W212', 'L12260', 'R14', 1480, 'R14', 'house', '2', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W213', 'L12264', 'R2', 650, 'R2', 'apartment', '1', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W214', 'L12264', 'R6', 920, 'R6', 'apartment', '2', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W215', 'L12264', 'R10', 880, 'R10', 'house', '1', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W216', 'L12264', 'R14', 1200, 'R14', 'house', '2', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W217', 'L16888', 'R2', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W218', 'L16888', 'R6', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W219', 'L16888', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W22', 'L4765', 'R10', 2700, 'R10', 'house', '1', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W220', 'L16888', 'R14', 1600, 'R14', 'house', '2', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W221', 'L16887', 'R2', 1105, 'R2', 'apartment', '1', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W222', 'L16887', 'R6', 1665, 'R6', 'apartment', '2', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W223', 'L16887', 'R10', 1175, 'R10', 'house', '1', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W224', 'L16887', 'R14', 1725, 'R14', 'house', '2', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W225', 'L16898', 'R2', 709, 'R2', 'apartment', '1', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W226', 'L16898', 'R6', 869, 'R6', 'apartment', '2', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W227', 'L16898', 'R10', 925, 'R10', 'house', '1', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W228', 'L16898', 'R14', 1350, 'R14', 'house', '2', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W229', 'L16890', 'R2', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W23', 'L4765', 'R14', 3200, 'R14', 'house', '2', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W230', 'L16890', 'R6', 1325, 'R6', 'apartment', '2', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W231', 'L16890', 'R10', 975, 'R10', 'house', '1', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W232', 'L16890', 'R14', 1550, 'R14', 'house', '2', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W233', 'L14416', 'R2', 1165, 'R2', 'apartment', '1', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W234', 'L14416', 'R6', 1625, 'R6', 'apartment', '2', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W235', 'L14416', 'R10', 1400, 'R10', 'house', '1', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W236', 'L14416', 'R14', 1995, 'R14', 'house', '2', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W237', 'L14418', 'R2', 760, 'R2', 'apartment', '1', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W238', 'L14418', 'R6', 965, 'R6', 'apartment', '2', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W239', 'L14418', 'R10', 1185, 'R10', 'house', '1', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W24', 'L4765', 'R2', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W240', 'L14418', 'R14', 1340, 'R14', 'house', '2', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W241', 'L14419', 'R2', 1150, 'R2', 'apartment', '1', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W242', 'L14419', 'R6', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W243', 'L14419', 'R10', 1600, 'R10', 'house', '1', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W244', 'L14419', 'R14', 2150, 'R14', 'house', '2', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W25', 'L4770', 'R2', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W26', 'L4770', 'R6', 2100, 'R6', 'apartment', '2', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W27', 'L4770', 'R10', 1200, 'R10', 'house', '1', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W28', 'L4770', 'R14', 2100, 'R14', 'house', '2', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W29', 'L4794', 'R6', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W3', 'L9531', 'R14', 2000, 'R14', 'house', '2', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W30', 'L4794', 'R10', 2500, 'R10', 'house', '1', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W31', 'L4794', 'R14', 2750, 'R14', 'house', '2', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W32', 'L4794', 'R2', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W33', 'L4804', 'R6', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W34', 'L4804', 'R10', 2000, 'R10', 'house', '1', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W35', 'L4804', 'R14', 2950, 'R14', 'house', '2', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W36', 'L4804', 'R2', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W37', 'L11419', 'R2', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11419', 'New York', 'NY', 10002),
#  ('W38', 'L11419', 'R6', 3200, 'R6', 'apartment', '2', 'Y', 'N', 'L11419', 'New York', 'NY', 10002),
#  ('W39', 'L11421', 'R6', 4500, 'R6', 'apartment', '2', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W4', 'L9531', 'R2', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W40', 'L11421', 'R10', 4500, 'R10', 'house', '1', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W41', 'L11421', 'R14', 5500, 'R14', 'house', '2', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W42', 'L11421', 'R2', 3500, 'R2', 'apartment', '1', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W43', 'L11427', 'R6', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L11427', 'New York', 'NY', 10014),
#  ('W44', 'L11427', 'R2', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11427', 'New York', 'NY', 10014),
#  ('W45', 'L11431', 'R6', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W46', 'L11431', 'R10', 3200, 'R10', 'house', '1', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W47', 'L11431', 'R14', 3500, 'R14', 'house', '2', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W48', 'L11431', 'R2', 3400, 'R2', 'apartment', '1', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W49', 'L11434', 'R6', 4200, 'R6', 'apartment', '2', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W5', 'L9532', 'R6', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W50', 'L11434', 'R10', 3000, 'R10', 'house', '1', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W51', 'L11434', 'R14', 3900, 'R14', 'house', '2', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W52', 'L11434', 'R2', 3600, 'R2', 'apartment', '1', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W53', 'L11480', 'R6', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W54', 'L11480', 'R10', 2500, 'R10', 'house', '1', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W55', 'L11480', 'R14', 3000, 'R14', 'house', '2', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W56', 'L11480', 'R2', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W57', 'L11495', 'R6', 3900, 'R6', 'apartment', '2', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W58', 'L11495', 'R10', 2800, 'R10', 'house', '1', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W59', 'L11495', 'R14', 3500, 'R14', 'house', '2', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W6', 'L9532', 'R10', 900, 'R10', 'house', '1', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W60', 'L11495', 'R2', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W61', 'L1734', 'R6', 2695, 'R6', 'apartment', '2', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W62', 'L1734', 'R10', 3000, 'R10', 'house', '1', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W63', 'L1734', 'R14', 4000, 'R14', 'house', '2', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W64', 'L1734', 'R2', 2295, 'R2', 'apartment', '1', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W65', 'L1735', 'R6', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W66', 'L1735', 'R10', 3300, 'R10', 'house', '1', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W67', 'L1735', 'R14', 4500, 'R14', 'house', '2', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W68', 'L1735', 'R2', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W69', 'L1736', 'R2', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W7', 'L9532', 'R14', 1100, 'R14', 'house', '2', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W70', 'L1736', 'R6', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W71', 'L1736', 'R10', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W72', 'L1736', 'R14', 4900, 'R14', 'house', '2', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W73', 'L1737', 'R6', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W74', 'L1737', 'R10', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W75', 'L1737', 'R14', 4200, 'R14', 'house', '2', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W76', 'L1737', 'R2', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W77', 'L1738', 'R2', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W78', 'L1738', 'R6', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W79', 'L1738', 'R10', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W8', 'L9532', 'R2', 500, 'R2', 'apartment', '1', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W80', 'L1738', 'R14', 4200, 'R14', 'house', '2', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W81', 'L1940', 'R6', 3600, 'R6', 'apartment', '2', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W82', 'L1940', 'R10', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W83', 'L1940', 'R14', 5500, 'R14', 'house', '2', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W84', 'L1940', 'R2', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W85', 'L1941', 'R6', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W86', 'L1941', 'R10', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W87', 'L1941', 'R14', 5000, 'R14', 'house', '2', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W88', 'L1941', 'R2', 3200, 'R2', 'apartment', '1', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W89', 'L1942', 'R6', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W9', 'L9533', 'R2', 965, 'R2', 'apartment', '1', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W90', 'L1942', 'R10', 3200, 'R10', 'house', '1', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W91', 'L1942', 'R14', 3500, 'R14', 'house', '2', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W92', 'L1942', 'R2', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W93', 'L1943', 'R2', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W94', 'L1943', 'R6', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W95', 'L1943', 'R10', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W96', 'L1943', 'R14', 5100, 'R14', 'house', '2', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W97', 'L1944', 'R6', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W98', 'L1944', 'R10', 5000, 'R10', 'house', '1', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W99', 'L1944', 'R14', 6000, 'R14', 'house', '2', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129)]

# %%
# %%sql
# SELECT ws.ws_property_id AS ws_id, ws.location AS ws_location, ws.ws_property_id AS ws_id, ws.property_type AS ws_type,
#         strp.sample_nightly_rent_price AS sample_price
# FROM watershed_property_info ws
# LEFT JOIN st_rental_prices strp ON strp.location = ws.location AND strp.property_type = ws.property_type
# Out:
# 244 rows affected.
# [('W1', 'L9531', 'W1', 'R6', 148),
#  ('W10', 'L9533', 'W10', 'R6', 133),
#  ('W100', 'L1944', 'W100', 'R2', 372),
#  ('W101', 'L15257', 'W101', 'R2', 302),
#  ('W102', 'L15257', 'W102', 'R6', 429),
#  ('W103', 'L15257', 'W103', 'R10', 380),
#  ('W104', 'L15257', 'W104', 'R14', 374),
#  ('W105', 'L15260', 'W105', 'R2', 386),
#  ('W106', 'L15260', 'W106', 'R6', 212),
#  ('W107', 'L15260', 'W107', 'R10', 969),
#  ('W108', 'L15260', 'W108', 'R14', 885),
#  ('W109', 'L15264', 'W109', 'R2', 287),
#  ('W11', 'L9533', 'W11', 'R10', 206),
#  ('W110', 'L15264', 'W110', 'R6', 462),
#  ('W111', 'L15264', 'W111', 'R10', 389),
#  ('W112', 'L15264', 'W112', 'R14', 678),
#  ('W113', 'L15278', 'W113', 'R2', 163),
#  ('W114', 'L15278', 'W114', 'R6', 374),
#  ('W115', 'L15278', 'W115', 'R10', 444),
#  ('W116', 'L15278', 'W116', 'R14', 426),
#  ('W117', 'L15280', 'W117', 'R2', 332),
#  ('W118', 'L15280', 'W118', 'R6', 430),
#  ('W119', 'L15280', 'W119', 'R10', 662),
#  ('W12', 'L9533', 'W12', 'R14', 186),
#  ('W120', 'L15280', 'W120', 'R14', 696),
#  ('W121', 'L463', 'W121', 'R2', 182),
#  ('W122', 'L463', 'W122', 'R6', 241),
#  ('W123', 'L463', 'W123', 'R10', 363),
#  ('W124', 'L463', 'W124', 'R14', 301),
#  ('W125', 'L464', 'W125', 'R2', 212),
#  ('W126', 'L464', 'W126', 'R6', 340),
#  ('W127', 'L464', 'W127', 'R10', 266),
#  ('W128', 'L464', 'W128', 'R14', 442),
#  ('W129', 'L2314', 'W129', 'R2', 354),
#  ('W13', 'L9534', 'W13', 'R6', 123),
#  ('W130', 'L2314', 'W130', 'R6', 377),
#  ('W131', 'L2314', 'W131', 'R10', 318),
#  ('W132', 'L2314', 'W132', 'R14', 198),
#  ('W133', 'L2318', 'W133', 'R2', 149),
#  ('W134', 'L2318', 'W134', 'R6', 210),
#  ('W135', 'L2318', 'W135', 'R10', 187),
#  ('W136', 'L2318', 'W136', 'R14', 225),
#  ('W137', 'L2323', 'W137', 'R2', 123),
#  ('W138', 'L2323', 'W138', 'R6', 263),
#  ('W139', 'L2323', 'W139', 'R10', 238),
#  ('W14', 'L9534', 'W14', 'R10', 146),
#  ('W140', 'L2323', 'W140', 'R14', 349),
#  ('W141', 'L2325', 'W141', 'R2', 147),
#  ('W142', 'L2325', 'W142', 'R6', 151),
#  ('W143', 'L2325', 'W143', 'R10', 429),
#  ('W144', 'L2325', 'W144', 'R14', 441),
#  ('W145', 'L2338', 'W145', 'R2', 144),
#  ('W146', 'L2338', 'W146', 'R6', 136),
#  ('W147', 'L2338', 'W147', 'R10', 305),
#  ('W148', 'L2338', 'W148', 'R14', 425),
#  ('W149', 'L3244', 'W149', 'R2', 176),
#  ('W15', 'L9534', 'W15', 'R14', 169),
#  ('W150', 'L3244', 'W150', 'R6', 207),
#  ('W151', 'L3244', 'W151', 'R10', 244),
#  ('W152', 'L3244', 'W152', 'R14', 536),
#  ('W153', 'L3256', 'W153', 'R2', 476),
#  ('W154', 'L3256', 'W154', 'R6', 360),
#  ('W155', 'L3256', 'W155', 'R10', 1477),
#  ('W156', 'L3256', 'W156', 'R14', 1265),
#  ('W157', 'L3261', 'W157', 'R2', 328),
#  ('W158', 'L3261', 'W158', 'R6', 246),
#  ('W159', 'L3261', 'W159', 'R10', 325),
#  ('W16', 'L9534', 'W16', 'R2', 94),
#  ('W160', 'L3261', 'W160', 'R14', 428),
#  ('W161', 'L3262', 'W161', 'R2', 188),
#  ('W162', 'L3262', 'W162', 'R6', 274),
#  ('W163', 'L3262', 'W163', 'R10', 860),
#  ('W164', 'L3262', 'W164', 'R14', 729),
#  ('W165', 'L3264', 'W165', 'R2', 174),
#  ('W166', 'L3264', 'W166', 'R6', 308),
#  ('W167', 'L3264', 'W167', 'R10', 308),
#  ('W168', 'L3264', 'W168', 'R14', 342),
#  ('W169', 'L10126', 'W169', 'R2', 229),
#  ('W17', 'L4761', 'W17', 'R6', 392),
#  ('W170', 'L10126', 'W170', 'R6', 322),
#  ('W171', 'L10126', 'W171', 'R10', 257),
#  ('W172', 'L10126', 'W172', 'R14', 286),
#  ('W173', 'L10130', 'W173', 'R2', 180),
#  ('W174', 'L10130', 'W174', 'R6', 230),
#  ('W175', 'L10130', 'W175', 'R10', 221),
#  ('W176', 'L10130', 'W176', 'R14', 316),
#  ('W177', 'L10133', 'W177', 'R2', 245),
#  ('W178', 'L10133', 'W178', 'R6', 266),
#  ('W179', 'L10133', 'W179', 'R10', 325),
#  ('W18', 'L4761', 'W18', 'R10', 393),
#  ('W180', 'L10133', 'W180', 'R14', 256),
#  ('W181', 'L10136', 'W181', 'R2', 184),
#  ('W182', 'L10136', 'W182', 'R6', 427),
#  ('W183', 'L10136', 'W183', 'R10', 418),
#  ('W184', 'L10136', 'W184', 'R14', 219),
#  ('W185', 'L1882', 'W185', 'R2', 220),
#  ('W186', 'L1882', 'W186', 'R6', 481),
#  ('W187', 'L1882', 'W187', 'R10', 280),
#  ('W188', 'L1882', 'W188', 'R14', 568),
#  ('W189', 'L1883', 'W189', 'R2', 318),
#  ('W19', 'L4761', 'W19', 'R14', 556),
#  ('W190', 'L1883', 'W190', 'R6', 538),
#  ('W191', 'L1883', 'W191', 'R10', 318),
#  ('W192', 'L1883', 'W192', 'R14', 680),
#  ('W193', 'L1887', 'W193', 'R2', 202),
#  ('W194', 'L1887', 'W194', 'R6', 579),
#  ('W195', 'L1887', 'W195', 'R10', 524),
#  ('W196', 'L1887', 'W196', 'R14', 560),
#  ('W197', 'L1902', 'W197', 'R2', 362),
#  ('W198', 'L1902', 'W198', 'R6', 417),
#  ('W199', 'L1902', 'W199', 'R10', 474),
#  ('W2', 'L9531', 'W2', 'R10', 146),
#  ('W20', 'L4761', 'W20', 'R2', 312),
#  ('W200', 'L1902', 'W200', 'R14', 491),
#  ('W201', 'L1916', 'W201', 'R2', 204),
#  ('W202', 'L1916', 'W202', 'R6', 245),
#  ('W203', 'L1916', 'W203', 'R10', 197),
#  ('W204', 'L1916', 'W204', 'R14', 195),
#  ('W205', 'L12252', 'W205', 'R2', 124),
#  ('W206', 'L12252', 'W206', 'R6', 156),
#  ('W207', 'L12252', 'W207', 'R10', 256),
#  ('W208', 'L12252', 'W208', 'R14', 284),
#  ('W209', 'L12260', 'W209', 'R2', 128),
#  ('W21', 'L4765', 'W21', 'R6', 337),
#  ('W210', 'L12260', 'W210', 'R6', 139),
#  ('W211', 'L12260', 'W211', 'R10', 240),
#  ('W212', 'L12260', 'W212', 'R14', 249),
#  ('W213', 'L12264', 'W213', 'R2', 107),
#  ('W214', 'L12264', 'W214', 'R6', 147),
#  ('W215', 'L12264', 'W215', 'R10', 246),
#  ('W216', 'L12264', 'W216', 'R14', 169),
#  ('W217', 'L16888', 'W217', 'R2', 174),
#  ('W218', 'L16888', 'W218', 'R6', 203),
#  ('W219', 'L16888', 'W219', 'R10', 240),
#  ('W22', 'L4765', 'W22', 'R10', 389),
#  ('W220', 'L16888', 'W220', 'R14', 312),
#  ('W221', 'L16887', 'W221', 'R2', 111),
#  ('W222', 'L16887', 'W222', 'R6', 169),
#  ('W223', 'L16887', 'W223', 'R10', 201),
#  ('W224', 'L16887', 'W224', 'R14', 242),
#  ('W225', 'L16898', 'W225', 'R2', 158),
#  ('W226', 'L16898', 'W226', 'R6', 246),
#  ('W227', 'L16898', 'W227', 'R10', 207),
#  ('W228', 'L16898', 'W228', 'R14', 224),
#  ('W229', 'L16890', 'W229', 'R2', 139),
#  ('W23', 'L4765', 'W23', 'R14', 325),
#  ('W230', 'L16890', 'W230', 'R6', 283),
#  ('W231', 'L16890', 'W231', 'R10', 192),
#  ('W232', 'L16890', 'W232', 'R14', 307),
#  ('W233', 'L14416', 'W233', 'R2', 180),
#  ('W234', 'L14416', 'W234', 'R6', 260),
#  ('W235', 'L14416', 'W235', 'R10', 232),
#  ('W236', 'L14416', 'W236', 'R14', 292),
#  ('W237', 'L14418', 'W237', 'R2', 169),
#  ('W238', 'L14418', 'W238', 'R6', 189),
#  ('W239', 'L14418', 'W239', 'R10', 289),
#  ('W24', 'L4765', 'W24', 'R2', 239),
#  ('W240', 'L14418', 'W240', 'R14', 278),
#  ('W241', 'L14419', 'W241', 'R2', 183),
#  ('W242', 'L14419', 'W242', 'R6', 237),
#  ('W243', 'L14419', 'W243', 'R10', 297),
#  ('W244', 'L14419', 'W244', 'R14', 360),
#  ('W25', 'L4770', 'W25', 'R2', 209),
#  ('W26', 'L4770', 'W26', 'R6', 265),
#  ('W27', 'L4770', 'W27', 'R10', 435),
#  ('W28', 'L4770', 'W28', 'R14', 487),
#  ('W29', 'L4794', 'W29', 'R6', 231),
#  ('W3', 'L9531', 'W3', 'R14', 199),
#  ('W30', 'L4794', 'W30', 'R10', 490),
#  ('W31', 'L4794', 'W31', 'R14', 538),
#  ('W32', 'L4794', 'W32', 'R2', 288),
#  ('W33', 'L4804', 'W33', 'R6', 415),
#  ('W34', 'L4804', 'W34', 'R10', 387),
#  ('W35', 'L4804', 'W35', 'R14', 575),
#  ('W36', 'L4804', 'W36', 'R2', 228),
#  ('W37', 'L11419', 'W37', 'R2', 337),
#  ('W38', 'L11419', 'W38', 'R6', 154),
#  ('W39', 'L11421', 'W39', 'R6', 432),
#  ('W4', 'L9531', 'W4', 'R2', 104),
#  ('W40', 'L11421', 'W40', 'R10', 200),
#  ('W41', 'L11421', 'W41', 'R14', 428),
#  ('W42', 'L11421', 'W42', 'R2', 576),
#  ('W43', 'L11427', 'W43', 'R6', 560),
#  ('W44', 'L11427', 'W44', 'R2', 288),
#  ('W45', 'L11431', 'W45', 'R6', 373),
#  ('W46', 'L11431', 'W46', 'R10', 420),
#  ('W47', 'L11431', 'W47', 'R14', 593),
#  ('W48', 'L11431', 'W48', 'R2', 436),
#  ('W49', 'L11434', 'W49', 'R6', 426),
#  ('W5', 'L9532', 'W5', 'R6', 142),
#  ('W50', 'L11434', 'W50', 'R10', 621),
#  ('W51', 'L11434', 'W51', 'R14', 535),
#  ('W52', 'L11434', 'W52', 'R2', 196),
#  ('W53', 'L11480', 'W53', 'R6', 294),
#  ('W54', 'L11480', 'W54', 'R10', 471),
#  ('W55', 'L11480', 'W55', 'R14', 620),
#  ('W56', 'L11480', 'W56', 'R2', 235),
#  ('W57', 'L11495', 'W57', 'R6', 284),
#  ('W58', 'L11495', 'W58', 'R10', 355),
#  ('W59', 'L11495', 'W59', 'R14', 436),
#  ('W6', 'L9532', 'W6', 'R10', 141),
#  ('W60', 'L11495', 'W60', 'R2', 250),
#  ('W61', 'L1734', 'W61', 'R6', 443),
#  ('W62', 'L1734', 'W62', 'R10', 343),
#  ('W63', 'L1734', 'W63', 'R14', 739),
#  ('W64', 'L1734', 'W64', 'R2', 270),
#  ('W65', 'L1735', 'W65', 'R6', 424),
#  ('W66', 'L1735', 'W66', 'R10', 980),
#  ('W67', 'L1735', 'W67', 'R14', 994),
#  ('W68', 'L1735', 'W68', 'R2', 284),
#  ('W69', 'L1736', 'W69', 'R2', 236),
#  ('W7', 'L9532', 'W7', 'R14', 188),
#  ('W70', 'L1736', 'W70', 'R6', 329),
#  ('W71', 'L1736', 'W71', 'R10', 549),
#  ('W72', 'L1736', 'W72', 'R14', 652),
#  ('W73', 'L1737', 'W73', 'R6', 378),
#  ('W74', 'L1737', 'W74', 'R10', 255),
#  ('W75', 'L1737', 'W75', 'R14', 441),
#  ('W76', 'L1737', 'W76', 'R2', 356),
#  ('W77', 'L1738', 'W77', 'R2', 437),
#  ('W78', 'L1738', 'W78', 'R6', 461),
#  ('W79', 'L1738', 'W79', 'R10', 669),
#  ('W8', 'L9532', 'W8', 'R2', 121),
#  ('W80', 'L1738', 'W80', 'R14', 437),
#  ('W81', 'L1940', 'W81', 'R6', 663),
#  ('W82', 'L1940', 'W82', 'R10', 337),
#  ('W83', 'L1940', 'W83', 'R14', 447),
#  ('W84', 'L1940', 'W84', 'R2', 610),
#  ('W85', 'L1941', 'W85', 'R6', 302),
#  ('W86', 'L1941', 'W86', 'R10', 213),
#  ('W87', 'L1941', 'W87', 'R14', 364),
#  ('W88', 'L1941', 'W88', 'R2', 251),
#  ('W89', 'L1942', 'W89', 'R6', 343),
#  ('W9', 'L9533', 'W9', 'R2', 125),
#  ('W90', 'L1942', 'W90', 'R10', 251),
#  ('W91', 'L1942', 'W91', 'R14', 404),
#  ('W92', 'L1942', 'W92', 'R2', 161),
#  ('W93', 'L1943', 'W93', 'R2', 408),
#  ('W94', 'L1943', 'W94', 'R6', 284),
#  ('W95', 'L1943', 'W95', 'R10', 443),
#  ('W96', 'L1943', 'W96', 'R14', 718),
#  ('W97', 'L1944', 'W97', 'R6', 478),
#  ('W98', 'L1944', 'W98', 'R10', 533),
#  ('W99', 'L1944', 'W99', 'R14', 566)]

# %%
# %%sql
# SELECT ws.ws_property_id AS ws_id, ws.location AS ws_location, ws.ws_property_id AS ws_id, ws.property_type AS ws_type,
#         sti.st_property_id AS samplt_id, strp.sample_nightly_rent_price AS sample_price, COUNT(DISTINCT strd.rental_date)/365 AS occupancy_rates
# FROM watershed_property_info ws
# LEFT JOIN st_rental_prices strp ON strp.location = ws.location AND strp.property_type = ws.property_type
# LEFT JOIN st_property_info sti ON sti.location = ws.location AND sti.property_type = ws.property_type
# LEFT JOIN st_rental_dates strd ON strd.st_property = sti.st_property_id
# WHERE ws.ws_property_id = 'W24' AND YEAR(strd.rental_date) = 2015
# GROUP BY sti.st_property_id
# Out:
# 1 rows affected.
# [('W24', 'L4765', 'W24', 'R2', 'ST424', 239, Decimal('0.6767'))]

# %% [markdown]
# ## Combine all datasets

# %%
# %%sql
# SELECT ws_property_id, properties.location_id, properties.property_type_id, current_monthly_rent, apt_house, num_bedrooms, kitchen, shared, city, state, zipcode,
#        st_property_id, percentile_10th_price, percentile_90th_price, sample_nightly_rent_price, occupancy_rate
# FROM
# (SELECT *
#  FROM watershed_property_info ws
#  LEFT JOIN property_type pt ON ws.property_type = pt.property_type_id
#  LEFT JOIN location loc ON ws.location = loc.location_id) AS properties
# LEFT JOIN st_rental_prices strp ON strp.location = properties.location AND strp.property_type = properties.property_type
# LEFT JOIN st_property_info sti ON sti.location = properties.location AND sti.property_type = properties.property_type
# LEFT JOIN
# (SELECT st_property, COUNT(DISTINCT rental_date)/365 AS occupancy_rate
#  FROM st_rental_dates
#  WHERE YEAR(rental_date) = 2015
#  GROUP BY st_property) AS occupancy
# ON occupancy.st_property = sti.st_property_id
# Out:
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060, 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514, 'ST1', 114, 153, 148, Decimal('0.1616')),
#  ('W10', 'L9533', 'R6', 1200, 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517, 'ST10', 111, 149, 133, Decimal('0.3479')),
#  ('W100', 'L1944', 'R2', 3300, 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94129, 'ST100', 108, 610, 372, Decimal('0.3973')),
#  ('W101', 'L15257', 'R2', 1400, 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78702, 'ST101', 178, 533, 302, Decimal('0.3644')),
#  ('W102', 'L15257', 'R6', 2000, 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78702, 'ST102', 221, 617, 429, Decimal('0.4110')),
#  ('W103', 'L15257', 'R10', 1600, 'house', '1', 'Y', 'N', 'Austin', 'TX', 78702, 'ST103', 202, 646, 380, Decimal('0.4110')),
#  ('W104', 'L15257', 'R14', 2800, 'house', '2', 'Y', 'N', 'Austin', 'TX', 78702, 'ST104', 197, 639, 374, Decimal('0.5260')),
#  ('W105', 'L15260', 'R2', 1100, 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78705, 'ST105', 114, 477, 386, Decimal('0.4329')),
#  ('W106', 'L15260', 'R6', 1900, 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78705, 'ST106', 80, 583, 212, Decimal('0.6959')),
#  ('W107', 'L15260', 'R10', 1800, 'house', '1', 'Y', 'N', 'Austin', 'TX', 78705, 'ST107', 239, 1431, 969, Decimal('0.1096')),
#  ('W108', 'L15260', 'R14', 3200, 'house', '2', 'Y', 'N', 'Austin', 'TX', 78705, 'ST108', 236, 1533, 885, Decimal('0.2247')),
#  ('W109', 'L15264', 'R2', 1000, 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78723, 'ST109', 138, 550, 287, Decimal('0.2192')),
#  ('W11', 'L9533', 'R10', 1000, 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517, 'ST11', 116, 296, 206, Decimal('0.3918')),
#  ('W110', 'L15264', 'R6', 1300, 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78723, 'ST110', 175, 917, 462, Decimal('0.5370')),
#  ('W111', 'L15264', 'R10', 1200, 'house', '1', 'Y', 'N', 'Austin', 'TX', 78723, 'ST111', 130, 821, 389, Decimal('0.5123')),
#  ('W112', 'L15264', 'R14', 1600, 'house', '2', 'Y', 'N', 'Austin', 'TX', 78723, 'ST112', 241, 866, 678, Decimal('0.3616')),
#  ('W113', 'L15278', 'R2', 800, 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78744, 'ST113', 134, 288, 163, Decimal('0.8438')),
#  ('W114', 'L15278', 'R6', 1200, 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78744, 'ST114', 234, 794, 374, Decimal('0.9151')),
#  ('W115', 'L15278', 'R10', 900, 'house', '1', 'Y', 'N', 'Austin', 'TX', 78744, 'ST115', 252, 547, 444, Decimal('0.4301')),
#  ('W116', 'L15278', 'R14', 1100, 'house', '2', 'Y', 'N', 'Austin', 'TX', 78744, 'ST116', 246, 616, 426, Decimal('0.4822')),
#  ('W117', 'L15280', 'R2', 1000, 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78746, 'ST117', 171, 457, 332, Decimal('0.4904')),
#  ('W118', 'L15280', 'R6', 1400, 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78746, 'ST118', 262, 567, 430, Decimal('0.5233')),
#  ('W119', 'L15280', 'R10', 1500, 'house', '1', 'Y', 'N', 'Austin', 'TX', 78746, 'ST119', 229, 859, 662, Decimal('0.4493')),
#  ('W12', 'L9533', 'R14', 1300, 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517, 'ST12', 136, 336, 186, Decimal('0.6603')),
#  ('W120', 'L15280', 'R14', 1600, 'house', '2', 'Y', 'N', 'Austin', 'TX', 78746, 'ST120', 449, 899, 696, Decimal('0.4877')),
#  ('W121', 'L463', 'R2', 600, 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72712, 'ST121', 132, 226, 182, Decimal('0.4384')),
#  ('W122', 'L463', 'R6', 800, 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72712, 'ST122', 157, 340, 241, Decimal('0.5315')),
#  ('W123', 'L463', 'R10', 700, 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72712, 'ST123', 215, 377, 363, Decimal('0.1397')),
#  ('W124', 'L463', 'R14', 1000, 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72712, 'ST124', 202, 374, 301, Decimal('0.4685')),
#  ('W125', 'L464', 'R2', 700, 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72719, 'ST125', 94, 356, 212, Decimal('0.5014')),
#  ('W126', 'L464', 'R6', 900, 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72719, 'ST126', 69, 485, 340, Decimal('0.3068')),
#  ('W127', 'L464', 'R10', 1000, 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72719, 'ST127', 84, 376, 266, Decimal('0.5205')),
#  ('W128', 'L464', 'R14', 1200, 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72719, 'ST128', 109, 490, 442, Decimal('0.1288')),
#  ('W129', 'L2314', 'R2', 1200, 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80204, 'ST129', 145, 434, 354, Decimal('0.2411')),
#  ('W13', 'L9534', 'R6', 920, 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707, 'ST13', 111, 147, 123, Decimal('0.4521')),
#  ('W130', 'L2314', 'R6', 1300, 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80204, 'ST130', 228, 457, 377, Decimal('0.4795')),
#  ('W131', 'L2314', 'R10', 1100, 'house', '1', 'Y', 'N', 'Denver', 'CO', 80204, 'ST131', 90, 375, 318, Decimal('0.2712')),
#  ('W132', 'L2314', 'R14', 1200, 'house', '2', 'Y', 'N', 'Denver', 'CO', 80204, 'ST132', 128, 238, 198, Decimal('0.4301')),
#  ('W133', 'L2318', 'R2', 1300, 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80209, 'ST133', 126, 188, 149, Decimal('0.5671')),
#  ('W134', 'L2318', 'R6', 1700, 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80209, 'ST134', 152, 247, 210, Decimal('0.3205')),
#  ('W135', 'L2318', 'R10', 1200, 'house', '1', 'Y', 'N', 'Denver', 'CO', 80209, 'ST135', 141, 263, 187, Decimal('0.4493')),
#  ('W136', 'L2318', 'R14', 1900, 'house', '2', 'Y', 'N', 'Denver', 'CO', 80209, 'ST136', 157, 314, 225, Decimal('0.5096')),
#  ('W137', 'L2323', 'R2', 1000, 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80218, 'ST137', 93, 159, 123, Decimal('0.7205')),
#  ('W138', 'L2323', 'R6', 1500, 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80218, 'ST138', 145, 462, 263, Decimal('0.4959')),
#  ('W139', 'L2323', 'R10', 1300, 'house', '1', 'Y', 'N', 'Denver', 'CO', 80218, 'ST139', 181, 316, 238, Decimal('0.4493')),
#  ('W14', 'L9534', 'R10', 850, 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707, 'ST14', 96, 245, 146, Decimal('0.5315')),
#  ('W140', 'L2323', 'R14', 1800, 'house', '2', 'Y', 'N', 'Denver', 'CO', 80218, 'ST140', 145, 412, 349, Decimal('0.1507')),
#  ('W141', 'L2325', 'R2', 1100, 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80220, 'ST141', 99, 215, 147, Decimal('0.6000')),
#  ('W142', 'L2325', 'R6', 1400, 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80220, 'ST142', 120, 188, 151, Decimal('0.5260')),
#  ('W143', 'L2325', 'R10', 1300, 'house', '1', 'Y', 'N', 'Denver', 'CO', 80220, 'ST143', 263, 489, 429, Decimal('0.2110')),
#  ('W144', 'L2325', 'R14', 1900, 'house', '2', 'Y', 'N', 'Denver', 'CO', 80220, 'ST144', 335, 502, 441, Decimal('0.3315')),
#  ('W145', 'L2338', 'R2', 900, 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80249, 'ST145', 98, 195, 144, Decimal('0.3288')),
#  ('W146', 'L2338', 'R6', 1400, 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80249, 'ST146', 77, 260, 136, Decimal('0.6192')),
#  ('W147', 'L2338', 'R10', 1400, 'house', '1', 'Y', 'N', 'Denver', 'CO', 80249, 'ST147', 173, 322, 305, Decimal('0.2712')),
#  ('W148', 'L2338', 'R14', 1700, 'house', '2', 'Y', 'N', 'Denver', 'CO', 80249, 'ST148', 176, 469, 425, Decimal('0.3288')),
#  ('W149', 'L3244', 'R2', 800, 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33122, 'ST149', 86, 224, 176, Decimal('0.4137')),
#  ('W15', 'L9534', 'R14', 900, 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707, 'ST15', 111, 276, 169, Decimal('0.4795')),
#  ('W150', 'L3244', 'R6', 1300, 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33122, 'ST150', 127, 276, 207, Decimal('0.6301')),
#  ('W151', 'L3244', 'R10', 1400, 'house', '1', 'Y', 'N', 'Miami', 'FL', 33122, 'ST151', 222, 381, 244, Decimal('0.9041')),
#  ('W152', 'L3244', 'R14', 1900, 'house', '2', 'Y', 'N', 'Miami', 'FL', 33122, 'ST152', 386, 773, 536, Decimal('0.5425')),
#  ('W153', 'L3256', 'R2', 1700, 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33137, 'ST153', 136, 476, 476, Decimal('0.0795')),
#  ('W154', 'L3256', 'R6', 2400, 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33137, 'ST154', 173, 690, 360, Decimal('0.5507')),
#  ('W155', 'L3256', 'R10', 2100, 'house', '1', 'Y', 'N', 'Miami', 'FL', 33137, 'ST155', 448, 2128, 1477, Decimal('0.6932')),
#  ('W156', 'L3256', 'R14', 3200, 'house', '2', 'Y', 'N', 'Miami', 'FL', 33137, 'ST156', 450, 2699, 1265, Decimal('0.7151')),
#  ('W157', 'L3261', 'R2', 1300, 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33146, 'ST157', 291, 387, 328, Decimal('0.5205')),
#  ('W158', 'L3261', 'R6', 1700, 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33146, 'ST158', 203, 318, 246, Decimal('0.1589')),
#  ('W159', 'L3261', 'R10', 1400, 'house', '1', 'Y', 'N', 'Miami', 'FL', 33146, 'ST159', 287, 395, 325, Decimal('0.5452')),
#  ('W16', 'L9534', 'R2', 750, 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707, 'ST16', 51, 179, 94, Decimal('0.4795')),
#  ('W160', 'L3261', 'R14', 1900, 'house', '2', 'Y', 'N', 'Miami', 'FL', 33146, 'ST160', 376, 502, 428, Decimal('0.5863')),
#  ('W161', 'L3262', 'R2', 1600, 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33149, 'ST161', 126, 352, 188, Decimal('0.6795')),
#  ('W162', 'L3262', 'R6', 2200, 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33149, 'ST162', 119, 505, 274, Decimal('0.5781')),
#  ('W163', 'L3262', 'R10', 1500, 'house', '1', 'Y', 'N', 'Miami', 'FL', 33149, 'ST163', 486, 1215, 860, Decimal('0.4110')),
#  ('W164', 'L3262', 'R14', 2400, 'house', '2', 'Y', 'N', 'Miami', 'FL', 33149, 'ST164', 516, 1650, 729, Decimal('0.6822')),
#  ('W165', 'L3264', 'R2', 1600, 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33178, 'ST165', 160, 321, 174, Decimal('0.8247')),
#  ('W166', 'L3264', 'R6', 1900, 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33178, 'ST166', 168, 364, 308, Decimal('0.2164')),
#  ('W167', 'L3264', 'R10', 1400, 'house', '1', 'Y', 'N', 'Miami', 'FL', 33178, 'ST167', 226, 368, 308, Decimal('0.6000')),
#  ('W168', 'L3264', 'R14', 2000, 'house', '2', 'Y', 'N', 'Miami', 'FL', 33178, 'ST168', 285, 428, 342, Decimal('0.3918')),
#  ('W169', 'L10126', 'R2', 1000, 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68046, 'ST169', 91, 342, 229, Decimal('0.5890')),
#  ('W17', 'L4761', 'R6', 2500, 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60607, 'ST17', 173, 581, 392, Decimal('0.2932')),
#  ('W170', 'L10126', 'R6', 1400, 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68046, 'ST170', 168, 392, 322, Decimal('0.2712')),
#  ('W171', 'L10126', 'R10', 1300, 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68046, 'ST171', 155, 494, 257, Decimal('0.5507')),
#  ('W172', 'L10126', 'R14', 1800, 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68046, 'ST172', 151, 391, 286, Decimal('0.4521')),
#  ('W173', 'L10130', 'R2', 700, 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68106, 'ST173', 99, 265, 180, Decimal('0.5178')),
#  ('W174', 'L10130', 'R6', 900, 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68106, 'ST174', 154, 286, 230, Decimal('0.5205')),
#  ('W175', 'L10130', 'R10', 1000, 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68106, 'ST175', 190, 462, 221, Decimal('0.6301')),
#  ('W176', 'L10130', 'R14', 1200, 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68106, 'ST176', 205, 411, 316, Decimal('0.3699')),
#  ('W177', 'L10133', 'R2', 700, 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68110, 'ST177', 192, 313, 245, Decimal('0.5699')),
#  ('W178', 'L10133', 'R6', 1000, 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68110, 'ST178', 192, 357, 266, Decimal('0.4192')),
#  ('W179', 'L10133', 'R10', 800, 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68110, 'ST179', 186, 465, 325, Decimal('0.4548')),
#  ('W18', 'L4761', 'R10', 2500, 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60607, 'ST18', 189, 588, 393, Decimal('0.6219')),
#  ('W180', 'L10133', 'R14', 900, 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68110, 'ST180', 209, 358, 256, Decimal('0.7096')),
#  ('W181', 'L10136', 'R2', 700, 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68114, 'ST181', 42, 252, 184, Decimal('0.3096')),
#  ('W182', 'L10136', 'R6', 1000, 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68114, 'ST182', 94, 531, 427, Decimal('0.2411')),
#  ('W183', 'L10136', 'R10', 900, 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68114, 'ST183', 86, 488, 418, Decimal('0.0466')),
#  ('W184', 'L10136', 'R14', 1200, 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68114, 'ST184', 83, 556, 219, Decimal('0.6356')),
#  ('W185', 'L1882', 'R2', 1100, 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91910, 'ST185', 84, 301, 220, Decimal('0.4301')),
#  ('W186', 'L1882', 'R6', 1400, 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91910, 'ST186', 134, 568, 481, Decimal('0.3808')),
#  ('W187', 'L1882', 'R10', 1300, 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91910, 'ST187', 109, 615, 280, Decimal('0.4575')),
#  ('W188', 'L1882', 'R14', 1900, 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91910, 'ST488', 227, 861, 568, Decimal('0.1890')),
#  ('W189', 'L1883', 'R2', 900, 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91950, 'ST489', 176, 440, 318, Decimal('0.2904')),
#  ('W19', 'L4761', 'R14', 2800, 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60607, 'ST19', 191, 826, 556, Decimal('0.2986')),
#  ('W190', 'L1883', 'R6', 1100, 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91950, 'ST490', 225, 1033, 538, Decimal('0.5808')),
#  ('W191', 'L1883', 'R10', 1300, 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91950, 'ST191', 157, 471, 318, Decimal('0.3918')),
#  ('W192', 'L1883', 'R14', 1600, 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91950, 'ST192', 253, 886, 680, Decimal('0.3863')),
#  ('W193', 'L1887', 'R2', 1400, 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92102, 'ST193', 76, 342, 202, Decimal('0.4877')),
#  ('W194', 'L1887', 'R6', 2000, 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92102, 'ST194', 107, 781, 579, Decimal('0.4110')),
#  ('W195', 'L1887', 'R10', 1700, 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92102, 'ST195', 162, 614, 524, Decimal('0.5041')),
#  ('W196', 'L1887', 'R14', 2500, 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92102, 'ST196', 158, 906, 560, Decimal('0.2767')),
#  ('W197', 'L1902', 'R2', 1800, 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92118, 'ST197', 199, 432, 362, Decimal('0.3288')),
#  ('W198', 'L1902', 'R6', 2600, 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92118, 'ST198', 366, 594, 417, Decimal('0.5315')),
#  ('W199', 'L1902', 'R10', 2500, 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92118, 'ST199', 333, 665, 474, Decimal('0.4274')),
#  ('W2', 'L9531', 'R10', 1500, 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514, 'ST2', 81, 205, 146, Decimal('0.2411')),
#  ('W20', 'L4761', 'R2', 1700, 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60607, 'ST20', 106, 465, 312, Decimal('0.4110')),
#  ('W200', 'L1902', 'R14', 3600, 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92118, 'ST200', 336, 624, 491, Decimal('0.3973')),
#  ('W201', 'L1916', 'R2', 1200, 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92154, 'ST201', 173, 395, 204, Decimal('0.7973')),
#  ('W202', 'L1916', 'R6', 1600, 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92154, 'ST202', 228, 456, 245, Decimal('0.6877')),
#  ('W203', 'L1916', 'R10', 1000, 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92154, 'ST203', 155, 252, 197, Decimal('0.5890')),
#  ('W204', 'L1916', 'R14', 1500, 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92154, 'ST204', 158, 236, 195, Decimal('0.6192')),
#  ('W205', 'L12252', 'R2', 750, 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43201, 'ST205', 89, 155, 124, Decimal('0.4548')),
#  ('W206', 'L12252', 'R6', 1040, 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43201, 'ST206', 115, 179, 156, Decimal('0.4877')),
#  ('W207', 'L12252', 'R10', 900, 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43201, 'ST207', 152, 300, 256, Decimal('0.4795')),
#  ('W208', 'L12252', 'R14', 1400, 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43201, 'ST208', 175, 368, 284, Decimal('0.4932')),
#  ('W209', 'L12260', 'R2', 825, 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43212, 'ST209', 77, 161, 128, Decimal('0.3616')),
#  ('W21', 'L4765', 'R6', 2700, 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60611, 'ST21', 157, 526, 337, Decimal('0.4219')),
#  ('W210', 'L12260', 'R6', 1300, 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43212, 'ST210', 125, 170, 139, Decimal('0.7425')),
#  ('W211', 'L12260', 'R10', 1000, 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43212, 'ST211', 140, 288, 240, Decimal('0.3699')),
#  ('W212', 'L12260', 'R14', 1480, 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43212, 'ST512', 175, 310, 249, Decimal('0.4411')),
#  ('W213', 'L12264', 'R2', 650, 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43222, 'ST513', 80, 156, 107, Decimal('0.4795')),
#  ('W214', 'L12264', 'R6', 920, 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43222, 'ST514', 108, 205, 147, Decimal('0.4137')),
#  ('W215', 'L12264', 'R10', 880, 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43222, 'ST515', 145, 333, 246, Decimal('0.4438')),
#  ('W216', 'L12264', 'R14', 1200, 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43222, 'ST516', 160, 310, 169, Decimal('0.6192')),
#  ('W217', 'L16888', 'R2', 1000, 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23113, 'ST517', 95, 280, 174, Decimal('0.5479')),
#  ('W218', 'L16888', 'R6', 1200, 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23113, 'ST218', 125, 277, 203, Decimal('0.2712')),
#  ('W219', 'L16888', 'R10', 1400, 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23113, 'ST219', 209, 384, 240, Decimal('0.7616')),
#  ('W22', 'L4765', 'R10', 2700, 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60611, 'ST422', 202, 629, 389, Decimal('0.5123')),
#  ('W220', 'L16888', 'R14', 1600, 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23113, 'ST220', 220, 418, 312, Decimal('0.6082')),
#  ('W221', 'L16887', 'R2', 1105, 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23060, 'ST221', 82, 235, 111, Decimal('0.6110')),
#  ('W222', 'L16887', 'R6', 1665, 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23060, 'ST222', 130, 200, 169, Decimal('0.3068')),
#  ('W223', 'L16887', 'R10', 1175, 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23060, 'ST223', 106, 267, 201, Decimal('0.5233')),
#  ('W224', 'L16887', 'R14', 1725, 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23060, 'ST224', 195, 305, 242, Decimal('0.4822')),
#  ('W225', 'L16898', 'R2', 709, 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23234, 'ST225', 86, 192, 158, Decimal('0.2219')),
#  ('W226', 'L16898', 'R6', 869, 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23234, 'ST226', 135, 305, 246, Decimal('0.3890')),
#  ('W227', 'L16898', 'R10', 925, 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23234, 'ST227', 125, 288, 207, Decimal('0.4164')),
#  ('W228', 'L16898', 'R14', 1350, 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23234, 'ST228', 119, 360, 224, Decimal('0.4849')),
#  ('W229', 'L16890', 'R2', 900, 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23220, 'ST229', 89, 177, 139, Decimal('0.5507')),
#  ('W23', 'L4765', 'R14', 3200, 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60611, 'ST423', 195, 844, 325, Decimal('0.8164')),
#  ('W230', 'L16890', 'R6', 1325, 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23220, 'ST230', 161, 319, 283, Decimal('0.2932')),
#  ('W231', 'L16890', 'R10', 975, 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23220, 'ST231', 145, 300, 192, Decimal('0.5014')),
#  ('W232', 'L16890', 'R14', 1550, 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23220, 'ST232', 185, 376, 307, Decimal('0.3014')),
#  ('W233', 'L14416', 'R2', 1165, 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29438, 'ST519', 135, 220, 180, Decimal('0.3425')),
#  ('W234', 'L14416', 'R6', 1625, 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29438, 'ST520', 220, 312, 260, Decimal('0.6000')),
#  ('W235', 'L14416', 'R10', 1400, 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29438, 'ST235', 135, 287, 232, Decimal('0.4986')),
#  ('W236', 'L14416', 'R14', 1995, 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29438, 'ST236', 224, 331, 292, Decimal('0.6384')),
#  ('W237', 'L14418', 'R2', 760, 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29470, 'ST237', 100, 195, 169, Decimal('0.2904')),
#  ('W238', 'L14418', 'R6', 965, 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29470, 'ST238', 135, 284, 189, Decimal('0.5397')),
#  ('W239', 'L14418', 'R10', 1185, 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29470, 'ST239', 157, 320, 289, Decimal('0.2795')),
#  ('W24', 'L4765', 'R2', 1700, 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60611, 'ST424', 98, 430, 239, Decimal('0.6767')),
#  ('W240', 'L14418', 'R14', 1340, 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29470, 'ST240', 135, 347, 278, Decimal('0.3890')),
#  ('W241', 'L14419', 'R2', 1150, 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29487, 'ST241', 80, 267, 183, Decimal('0.5753')),
#  ('W242', 'L14419', 'R6', 2000, 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29487, 'ST242', 160, 323, 237, Decimal('0.3123')),
#  ('W243', 'L14419', 'R10', 1600, 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29487, 'ST243', 225, 406, 297, Decimal('0.4521')),
#  ('W244', 'L14419', 'R14', 2150, 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29487, 'ST244', 170, 447, 360, Decimal('0.5315')),
#  ('W25', 'L4770', 'R2', 1600, 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60616, 'ST425', 94, 411, 209, Decimal('0.5397')),
#  ('W26', 'L4770', 'R6', 2100, 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60616, 'ST426', 130, 438, 265, Decimal('0.4027')),
#  ('W27', 'L4770', 'R10', 1200, 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60616, 'ST427', 162, 504, 435, Decimal('0.4000')),
#  ('W28', 'L4770', 'R14', 2100, 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60616, 'ST428', 175, 755, 487, Decimal('0.4301')),
#  ('W29', 'L4794', 'R6', 2500, 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60642, 'ST429', 129, 431, 231, Decimal('0.4027')),
#  ('W3', 'L9531', 'R14', 2000, 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514, 'ST3', 97, 240, 199, Decimal('0.3123')),
#  ('W30', 'L4794', 'R10', 2500, 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60642, 'ST430', 186, 578, 490, Decimal('0.2301')),
#  ('W31', 'L4794', 'R14', 2750, 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60642, 'ST31', 188, 810, 538, Decimal('0.6000')),
#  ('W32', 'L4794', 'R2', 1800, 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60642, 'ST32', 89, 390, 288, Decimal('0.2329')),
#  ('W33', 'L4804', 'R6', 3000, 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60654, 'ST33', 193, 648, 415, Decimal('0.4082')),
#  ('W34', 'L4804', 'R10', 2000, 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60654, 'ST34', 193, 600, 387, Decimal('0.3260')),
#  ('W35', 'L4804', 'R14', 2950, 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60654, 'ST35', 192, 829, 575, Decimal('0.3890')),
#  ('W36', 'L4804', 'R2', 1700, 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60654, 'ST36', 98, 432, 228, Decimal('0.5205')),
#  ('W37', 'L11419', 'R2', 3000, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10002, 'ST37', 87, 512, 337, Decimal('0.4630')),
#  ('W38', 'L11419', 'R6', 3200, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10002, 'ST38', 154, 480, 154, Decimal('0.6795')),
#  ('W39', 'L11421', 'R6', 4500, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10004, 'ST39', 273, 853, 432, Decimal('0.6822')),
#  ('W4', 'L9531', 'R2', 800, 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514, 'ST4', 53, 188, 104, Decimal('0.5699')),
#  ('W40', 'L11421', 'R10', 4500, 'house', '1', 'Y', 'N', 'New York', 'NY', 10004, 'ST40', 103, 807, 200, Decimal('0.8685')),
#  ('W41', 'L11421', 'R14', 5500, 'house', '2', 'Y', 'N', 'New York', 'NY', 10004, 'ST41', 200, 770, 428, Decimal('0.5233')),
#  ('W42', 'L11421', 'R2', 3500, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10004, 'ST42', 151, 890, 576, Decimal('0.4603')),
#  ('W43', 'L11427', 'R6', 4000, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10014, 'ST43', 218, 681, 560, Decimal('0.3534')),
#  ('W44', 'L11427', 'R2', 3000, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10014, 'ST44', 109, 640, 288, Decimal('0.4986')),
#  ('W45', 'L11431', 'R6', 5600, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10019, 'ST45', 196, 612, 373, Decimal('0.5151')),
#  ('W46', 'L11431', 'R10', 3200, 'house', '1', 'Y', 'N', 'New York', 'NY', 10019, 'ST46', 165, 1296, 420, Decimal('0.8712')),
#  ('W47', 'L11431', 'R14', 3500, 'house', '2', 'Y', 'N', 'New York', 'NY', 10019, 'ST47', 268, 1032, 593, Decimal('0.5068')),
#  ('W48', 'L11431', 'R2', 3400, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10019, 'ST48', 106, 624, 436, Decimal('0.2822')),
#  ('W49', 'L11434', 'R6', 4200, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10023, 'ST49', 210, 654, 426, Decimal('0.5425')),
#  ('W5', 'L9532', 'R6', 1100, 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516, 'ST5', 111, 148, 142, Decimal('0.0822')),
#  ('W50', 'L11434', 'R10', 3000, 'house', '1', 'Y', 'N', 'New York', 'NY', 10023, 'ST50', 133, 1040, 621, Decimal('0.3479')),
#  ('W51', 'L11434', 'R14', 3900, 'house', '2', 'Y', 'N', 'New York', 'NY', 10023, 'ST51', 231, 888, 535, Decimal('0.4767')),
#  ('W52', 'L11434', 'R2', 3600, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10023, 'ST52', 137, 808, 196, Decimal('0.7781')),
#  ('W53', 'L11480', 'R6', 3500, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11101, 'ST53', 155, 483, 294, Decimal('0.3973')),
#  ('W54', 'L11480', 'R10', 2500, 'house', '1', 'Y', 'N', 'New York', 'NY', 11101, 'ST54', 111, 868, 471, Decimal('0.6000')),
#  ('W55', 'L11480', 'R14', 3000, 'house', '2', 'Y', 'N', 'New York', 'NY', 11101, 'ST355', 195, 752, 620, Decimal('0.2932')),
#  ('W56', 'L11480', 'R2', 3000, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11101, 'ST356', 80, 469, 235, Decimal('0.6411')),
#  ('W57', 'L11495', 'R6', 3900, 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11211, 'ST357', 116, 361, 284, Decimal('0.5041')),
#  ('W58', 'L11495', 'R10', 2800, 'house', '1', 'Y', 'N', 'New York', 'NY', 11211, 'ST358', 102, 799, 355, Decimal('0.4027')),
#  ('W59', 'L11495', 'R14', 3500, 'house', '2', 'Y', 'N', 'New York', 'NY', 11211, 'ST359', 188, 724, 436, Decimal('0.5068')),
#  ('W6', 'L9532', 'R10', 900, 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516, 'ST6', 116, 296, 141, Decimal('0.5479')),
#  ('W60', 'L11495', 'R2', 2600, 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11211, 'ST360', 69, 406, 250, Decimal('0.3699')),
#  ('W61', 'L1734', 'R6', 2695, 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025, 'ST361', 265, 534, 443, Decimal('0.2356')),
#  ('W62', 'L1734', 'R10', 3000, 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025, 'ST362', 158, 706, 343, Decimal('0.5808')),
#  ('W63', 'L1734', 'R14', 4000, 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025, 'ST363', 306, 781, 739, Decimal('0.0192')),
#  ('W64', 'L1734', 'R2', 2295, 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025, 'ST364', 100, 469, 270, Decimal('0.4685')),
#  ('W65', 'L1735', 'R6', 3000, 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301, 'ST365', 270, 543, 424, Decimal('0.3425')),
#  ('W66', 'L1735', 'R10', 3300, 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301, 'ST366', 283, 1261, 980, Decimal('0.2712')),
#  ('W67', 'L1735', 'R14', 4500, 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301, 'ST67', 530, 1354, 994, Decimal('0.4301')),
#  ('W68', 'L1735', 'R2', 2700, 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301, 'ST68', 103, 483, 284, Decimal('0.6055')),
#  ('W69', 'L1736', 'R2', 2700, 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303, 'ST69', 110, 515, 236, Decimal('0.5671')),
#  ('W7', 'L9532', 'R14', 1100, 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516, 'ST7', 136, 335, 188, Decimal('0.6192')),
#  ('W70', 'L1736', 'R6', 3000, 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303, 'ST70', 270, 544, 329, Decimal('0.7041')),
#  ('W71', 'L1736', 'R10', 4500, 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303, 'ST71', 231, 1027, 549, Decimal('0.4438')),
#  ('W72', 'L1736', 'R14', 4900, 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303, 'ST72', 379, 969, 652, Decimal('0.4466')),
#  ('W73', 'L1737', 'R6', 3300, 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305, 'ST73', 264, 532, 378, Decimal('0.4219')),
#  ('W74', 'L1737', 'R10', 4500, 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305, 'ST74', 151, 673, 255, Decimal('0.5918')),
#  ('W75', 'L1737', 'R14', 4200, 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305, 'ST75', 278, 711, 441, Decimal('0.5726')),
#  ('W76', 'L1737', 'R2', 2500, 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305, 'ST76', 98, 460, 356, Decimal('0.4247')),
#  ('W77', 'L1738', 'R2', 2500, 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306, 'ST77', 108, 507, 437, Decimal('0.0795')),
#  ('W78', 'L1738', 'R6', 3300, 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306, 'ST78', 270, 543, 461, Decimal('0.3178')),
#  ('W79', 'L1738', 'R10', 4500, 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306, 'ST79', 186, 829, 669, Decimal('0.3123')),
#  ('W8', 'L9532', 'R2', 500, 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516, 'ST8', 50, 174, 121, Decimal('0.3973')),
#  ('W80', 'L1738', 'R14', 4200, 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306, 'ST80', 319, 815, 437, Decimal('0.6110')),
#  ('W81', 'L1940', 'R6', 3600, 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94103, 'ST81', 332, 805, 663, Decimal('0.2329')),
#  ('W82', 'L1940', 'R10', 4000, 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94103, 'ST82', 179, 629, 337, Decimal('0.5068')),
#  ('W83', 'L1940', 'R14', 5500, 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94103, 'ST83', 227, 813, 447, Decimal('0.6164')),
#  ('W84', 'L1940', 'R2', 3000, 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94103, 'ST84', 115, 650, 610, Decimal('0.1014')),
#  ('W85', 'L1941', 'R6', 4000, 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94110, 'ST85', 220, 534, 302, Decimal('0.3151')),
#  ('W86', 'L1941', 'R10', 4000, 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94110, 'ST86', 128, 450, 213, Decimal('0.6521')),
#  ('W87', 'L1941', 'R14', 5000, 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94110, 'ST87', 152, 546, 364, Decimal('0.5123')),
#  ('W88', 'L1941', 'R2', 3200, 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94110, 'ST88', 94, 528, 251, Decimal('0.6274')),
#  ('W89', 'L1942', 'R6', 3500, 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94112, 'ST89', 194, 471, 343, Decimal('0.3973')),
#  ('W9', 'L9533', 'R2', 965, 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517, 'ST9', 50, 174, 125, Decimal('0.3753')),
#  ('W90', 'L1942', 'R10', 3200, 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94112, 'ST90', 138, 485, 251, Decimal('0.3342')),
#  ('W91', 'L1942', 'R14', 3500, 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94112, 'ST91', 152, 547, 404, Decimal('0.3616')),
#  ('W92', 'L1942', 'R2', 3000, 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94112, 'ST92', 77, 432, 161, Decimal('0.2658')),
#  ('W93', 'L1943', 'R2', 2600, 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94118, 'ST93', 100, 565, 408, Decimal('0.3863')),
#  ('W94', 'L1943', 'R6', 4000, 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94118, 'ST94', 204, 494, 284, Decimal('0.3151')),
#  ('W95', 'L1943', 'R10', 4000, 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94118, 'ST95', 257, 903, 443, Decimal('0.5562')),
#  ('W96', 'L1943', 'R14', 5100, 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94118, 'ST96', 256, 916, 718, Decimal('0.4493')),
#  ('W97', 'L1944', 'R6', 5600, 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94129, 'ST97', 265, 644, 478, Decimal('0.3178')),
#  ('W98', 'L1944', 'R10', 5000, 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94129, 'ST98', 236, 829, 533, Decimal('0.5123')),
#  ('W99', 'L1944', 'R14', 6000, 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94129, 'ST99', 244, 872, 566, Decimal('0.3699'))]

# %%
dataset = %%sql \
SELECT ws_property_id, properties.location_id, properties.property_type_id, current_monthly_rent, apt_house, num_bedrooms, kitchen, shared, city, state, zipcode, \
       st_property_id, percentile_10th_price, percentile_90th_price, sample_nightly_rent_price, occupancy_rate \
FROM \
(SELECT * \
 FROM watershed_property_info ws \
 LEFT JOIN property_type pt ON ws.property_type = pt.property_type_id \
 LEFT JOIN location loc ON ws.location = loc.location_id) AS properties \
LEFT JOIN st_rental_prices strp ON strp.location = properties.location AND strp.property_type = properties.property_type \
LEFT JOIN st_property_info sti ON sti.location = properties.location AND sti.property_type = properties.property_type \
LEFT JOIN  \
(SELECT st_property, COUNT(DISTINCT rental_date)/365 AS occupancy_rate \
 FROM st_rental_dates \
 WHERE YEAR(rental_date) = 2015 \
 GROUP BY st_property) AS occupancy \
ON occupancy.st_property = sti.st_property_id \
# Out:
# 244 rows affected.

# %%
dataset.csv('project_dataset.csv')
# Out:
# CSV results at /home/jovyan/work/Capstone_course_materials/project_dataset.csv

# %% [markdown]
# # Quizes

# %% [markdown]
# **Q1: How many tables are there in the Watershed database?**

# %%
# %%sql
# SHOW tables
# Out:
# 6 rows affected.
# [('location',),
#  ('property_type',),
#  ('st_property_info',),
#  ('st_rental_dates',),
#  ('st_rental_prices',),
#  ('watershed_property_info',)]

# %% [markdown]
# **Q2: How many fields, or columns, are there in the property_type table?**

# %%
# %%sql
# DESCRIBE property_type
# Out:
# 5 rows affected.
# [('property_type_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('apt_house', 'varchar(255)', 'YES', '', None, ''),
#  ('num_bedrooms', 'varchar(255)', 'YES', '', None, ''),
#  ('kitchen', 'varchar(255)', 'YES', '', None, ''),
#  ('shared', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# **Q3: Which of the following things are true about Watershed property W106?**
#
# A. It’s a 1-bedroom house in San Francisco, CA
#
# B. It’s a 2-bedroom apartment in Austin, TX
#
# C. It’s a 1-bedroom apartment in Miami, FL
#
# D. It’s a 2-bedroom house in Chapel Hill, NC

# %%
# %%sql
# SELECT *
# FROM watershed_property_info ws
# LEFT JOIN property_type pt ON ws.property_type = pt.property_type_id
# LEFT JOIN location loc ON ws.location = loc.location_id
# WHERE ws_property_id = 'W106'
# Out:
# 1 rows affected.
# [('W106', 'L15260', 'R6', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705)]

# %% [markdown]
# **Q4: Which of the following things are true about the example short-term rental property that has the same type and is found in the same location as Watershed Property W24?**
#
# A. The nightly rental price is $180 and it’s occupancy rate in 2015 was 71.5%
#
# B. The nightly rental price is $220 and it’s occupancy rate in 2015 was 40.3%
#
# C. The nightly rental price is $239 and it’s occupancy rate in 2015 was 67.7%
#
# D. The nightly rental price is $283 and it’s occupancy rate in 2015 was 49.9%

# %%
# %%sql
# SELECT ws.ws_property_id AS ws_id, ws.location AS ws_location, ws.ws_property_id AS ws_id, ws.property_type AS ws_type,
#         sti.st_property_id AS samplt_id, strp.sample_nightly_rent_price AS sample_price, COUNT(DISTINCT strd.rental_date)/365 AS occupancy_rates
# FROM watershed_property_info ws
# LEFT JOIN st_rental_prices strp ON strp.location = ws.location AND strp.property_type = ws.property_type
# LEFT JOIN st_property_info sti ON sti.location = ws.location AND sti.property_type = ws.property_type
# LEFT JOIN st_rental_dates strd ON strd.st_property = sti.st_property_id
# WHERE ws.ws_property_id = 'W24' AND YEAR(strd.rental_date) = 2015
# GROUP BY sti.st_property_id
# Out:
# 1 rows affected.
# [('W24', 'L4765', 'W24', 'R2', 'ST424', 239, Decimal('0.6767'))]

# %% [markdown]
# ** Q5: How many of the client’s 244 Watershed properties have kitchens?**

# %%
# %%sql
# SELECT COUNT(*)
# FROM watershed_property_info ws
# LEFT JOIN property_type pt ON ws.property_type = pt.property_type_id
# LEFT JOIN location loc ON ws.location = loc.location_id
# WHERE kitchen = 'Y'
# Out:
# 1 rows affected.
# [(244,)]
